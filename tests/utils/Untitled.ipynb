# %%
"""
Running the script creates line-by-line transcriptions of the original word files.
Make sure the word files are in the folder utils/files.
"""
import os
import re
import docx

class TextTranscriber:
    """
    Makes a transcription of original word files line by line
    """

    def __init__(self, word_file_names, word_files_folder):
        self.word_file_names = word_file_names
        self.word_files_folder = word_files_folder
        self.line_texts = {}
        
        for word_file_name in self.word_file_names:
            path = os.path.join(self.word_files_folder, word_file_name)
            print(path)
            self.word_doc = docx.Document(path)
            self.read()
        
    def read(self):
        for para in self.word_doc.paragraphs:
            if re.match('KTU', para.text):
                self.corpus = para.text
            elif re.match('[LXVI+]', para.text):
                self.column = para.text
            elif re.match('^\d+', para.text):
                self.line = int(re.match('^\d+', para.text).group())
                self.text = re.sub('^\d+', '', para.text).lstrip()
                
                self.line_texts[(self.corpus, self.column, self.line)] = self.text

# %%
TextTranscriber(['KTU 1.2_text processed.docx'], 'files').line_texts
# Out:
# files\KTU 1.2_text processed.docx
# {('KTU 1.2',
#   'I',
#   1): '[ ]x[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   2): 'k ṯb . x[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   3): 'at . ypˤt . b a/r[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]\xa0',
#  ('KTU 1.2',
#   'I',
#   4): 'aliyn . bˤl . [ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   5): 'drk{.}tk . [[ṯ]]mšl[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   6): 'b rišk . aymr[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   7): 'ṯpṭ . nhr . yṯb[r \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0  ]',
#  ('KTU 1.2', 'I', 8): 'rišk . ˤṯtrt . š[m . bˤl . qdqd  . \xa0  ]',
#  ('KTU 1.2',
#   'I',
#   9): 'rˤt . mṭ . tpln . b gb[l  \xa0 \xa0 \xa0 \xa0 \xa0 \xa0   \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   10): 'ab . šnm . aṯtm . tq[ḥ\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0]',
#  ('KTU 1.2',
#   'I',
#   11): 'mlakm . ylak . ym . [  \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   12): '[b ]ˤlṣ ˤlṣm . npr . šm[m \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'I',
#   13): 'uṭ  . ṯbr . aphm . tbˤ . ġlm[m . al . tṯb . idk . pnm ] ',
#  ('KTU 1.2',
#   'I',
#   14): 'al . ttn . ˤm . pḫr . mˤd . t[k . ġr . ll . l pˤn . il ]',
#  ('KTU 1.2', 'I', 15): 'al . tpl . al . tštḥwy . pḫr . [mˤd . qmm . aṯr . am]',
#  ('KTU 1.2',
#   'I',
#   16): 'r ṯny . dˤtkm . w rgm . l ṯr . ab[ . il . ṯny . l pḫr]',
#  ('KTU 1.2', 'I', 17): 'mˤd . tḥm . ym . bˤlkm . adnkm . ṯpṭ[ . nhr]',
#  ('KTU 1.2',
#   'I',
#   18): 'tn . ilm . d tqh . d tqyn . hmlt . tn . bˤl[ . w ˤnnh]',
#  ('KTU 1.2',
#   'I',
#   19): 'bn . dgn . arṯm . pḏh . tbˤ . ġlmm . l yṯb . i[dk . pnm]',
#  ('KTU 1.2',
#   'I',
#   20): 'l ytn . tk . ġr . ll . ˤm . phr  . mˤd . ap . ilm . lḥ[m] ',
#  ('KTU 1.2',
#   'I',
#   21): 'yṯb . bn . qdš . l ṯr[[ . bˤl . ˤl . i]]m . bˤl . qm . ˤl . il . hlm',
#  ('KTU 1.2',
#   'I',
#   22): 'ilm . tphhm . tphn . mlak . ym . tˤd[[ṯpṭ]]t . ṯpṭ[ . nhr]',
#  ('KTU 1.2', 'I', 23): 'tġly . ilm . rišthm . l ẓr . brkthm . w l kḥṯ',
#  ('KTU 1.2', 'I', 24): 'zblhm . b hm . ygˤr bˤl . lm . ġltm . ilm . rišt',
#  ('KTU 1.2', 'I', 25): 'km . l ẓr . brktkm . w ln . kḥṯ . zblkm . aḥd',
#  ('KTU 1.2', 'I', 26): 'ilm . tˤny lḥt . mlak . ym . tˤdt . ṯpṭ . nh<r>',
#  ('KTU 1.2', 'I', 27): 'šu . ilm . raštkm . l ẓr . brktkm . ln kḥṯ',
#  ('KTU 1.2', 'I', 28): 'zblhm . w ank . ˤny . mlak . ym . tˤdt . ṯpṭ . nhr',
#  ('KTU 1.2',
#   'I',
#   29): 'tšu . ilm . rašthm . l ẓr . brkthm . ln[[h . ]] kḥṯ . zblhm .',
#  ('KTU 1.2', 'I', 30): 'aḫr . tmġyn . mlak ym . tˤdt . ṯpṭ . nhr . l pˤn . il',
#  ('KTU 1.2', 'I', 31): 'l tpl . l tštḥwy . pḫr . mˤd . [[m]]qmm . aṯr . amr',
#  ('KTU 1.2', 'I', 32): '[ṯn]y . dˤthm . išt . ištm . yitmr . ḥrb . lṭšt',
#  ('KTU 1.2', 'I', 33): '[lš]nhm . rgm . ṣ  ṯr . abh . il . tḥm . ym . bˤlkm',
#  ('KTU 1.2', 'I', 34): '[ad]nkm . ṯpṭ . nhr . tn . ilm . d tqh . d tqynh',
#  ('KTU 1.2', 'I', 35): '[hml]t . tn bˤl . w ˤnnh . bn . dgn . arṯm . pḏh',
#  ('KTU 1.2',
#   'I',
#   36): '[w yˤ]n . ṯr . abh . il . ˤbdk . bˤl . y ymm . ˤbdk . bˤl',
#  ('KTU 1.2', 'I', 37): '[nhr]m . bn . dgn . asrkm . hw . ybl . argmnk . k ilm',
#  ('KTU 1.2',
#   'I',
#   38): '[xxxx ]ybl . k bn . qdš . mnḥyk . ap . anš . zbl . bˤl',
#  ('KTU 1.2', 'I', 39): '[w yuḫ]d . b yd . mšḫṭ . bm . ymn . mḫṣ . ġlmm . yšu',
#  ('KTU 1.2',
#   'I',
#   40): '[xxx . ˤ]nt . tuḫd . šmalh . tuḫd . ˤṯtrt . ik . mḫ[ṣt]',
#  ('KTU 1.2', 'I', 41): '[xx . tˤ]dt . ṯpṭ . nhr . mlak . mṭḫr . yḥb[q . xxx]',
#  ('KTU 1.2',
#   'I',
#   42): '[xxxxx] . \xa0mlak . bn . ktpm . rgm . bˤlh . w . y[xxxxxx]',
#  ('KTU 1.2',
#   'I',
#   43): '[xxxxx]x . ap . anš . zbl . bˤl . šdmt . b gp[nm . xxxxx]',
#  ('KTU 1.2',
#   'I',
#   44): '[xxxxxx]dm . mlak . ym . tˤdt . ṯpṭ . nh[r xxxxxxx]\xa0',
#  ('KTU 1.2', 'I', 45): '[xxxxxxx] . an . rgmt . l ym . bˤlkm . ad[nkm . ṯpṭ]',
#  ('KTU 1.2',
#   'I',
#   46): '[nhr xxx ]šmˤ . hwt . gmr [.] hd . lwn . ym[ xxxxxxxx]',
#  ('KTU 1.2', 'I', 47): '[xxxxxxx]xx. iyxx [.]xx thbr . xx[xxxxxxxx]',
#  ('KTU 1.2',
#   'I',
#   48): '[ \xa0 \xa0 \xa0 \xa0 \xa0 ]xxx[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 1): 'bx[\xa0 \xa0 \xa0 \xa0 \xa0   ]',
#  ('KTU 1.2', 'II', 2): 'kx[\xa0 \xa0 \xa0 \xa0 \xa0   ]',
#  ('KTU 1.2', 'II', 3): 'tk .[\xa0 \xa0 \xa0 \xa0   ]',
#  ('KTU 1.2', 'II', 4): 'slp x[\xa0 \xa0 \xa0   ]',
#  ('KTU 1.2', 'II', 5): 'w . bˤl[\xa0 \xa0  ]',
#  ('KTU 1.2', 'II', 6): 'ik . ġb[\xa0 \xa0  ]',
#  ('KTU 1.2', 'II', 7): 'w . t[ \xa0 \xa0    ]',
#  ('KTU 1.2', 'II', 8): 'imḫṣ . [ \xa0  ]',
#  ('KTU 1.2', 'II', 9): 'mlk . kx[  ]',
#  ('KTU 1.2', 'II', 10): 'lakt lx[ \xa0  ]',
#  ('KTU 1.2', 'II', 11): 'npš[\xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 12): 'bˤl[ \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 13): 'w[ \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 14): 'ṯr[ \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 15): 'ḫl[ \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 16): 'kṯ[ \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 17): 'ml[\xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'II', 18): 'š[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2', 'III', 1): '[ \xa0 ]ad[ \xa0 ]n[ \xa0 ]',
#  ('KTU 1.2', 'III', 2): '[ \xa0 kpt]r . l rḥq [. i]l[m . ḥkpt . l rḥq ]',
#  ('KTU 1.2',
#   'III',
#   3): '[ilnym . ṯn . mṯpdm . tḥt . ˤnt . arṣ . ṯlṯ . mtḥ . ġyrm]',
#  ('KTU 1.2',
#   'III',
#   4): '[idk  .] l ytn [.] pnm . ˤm [. i]l . mbk . n[hrm . qrb . apq . thmtm]',
#  ('KTU 1.2',
#   'III',
#   5): '[ygly . ]ḏl  i[l] . w ybu [. q]rš . mlk [. ab . šnm . l pˤn . il]',
#  ('KTU 1.2',
#   'III',
#   6): '[yhbr .] w yql[ . y]štḥw[y .] w ykb[dnh aḫ]r [\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'III',
#   7): '[ \xa0 ]kṯr  . w ḫ[ss .] tbˤ . bn [.] bht . ym [. rm]m . hkl . ṯpṭ . n[hr ]',
#  ('KTU 1.2',
#   'III',
#   8): '[ \xa0 n]hr tk . [ \xa0 ]tbˤ . kṯr w[ ḫss . xx t]bn . bht  zbl ym',
#  ('KTU 1.2',
#   'III',
#   9): '[ \xa0 ]m  . hk[l . l ṯpṭ] . nhr . b tk  . u[pqt . ym \xa0 ]x[ \xa0 ]',
#  ('KTU 1.2',
#   'III',
#   10): '[ḥš . bh]th tbn[n . ḥ]š . trm[m . hk]l[h . alp . šd . aḫd  . ]bt',
#  ('KTU 1.2',
#   'III',
#   11): '[rbt .] kmn [.] hkl ušbš[ ym b]t b. ġlm . l šd mr ymm',
#  ('KTU 1.2',
#   'III',
#   12): '[bˤl ]b ym . ym . ymt. yˤm[d]n pn . ˤṯtr . d t[ \xa0 ]',
#  ('KTU 1.2',
#   'III',
#   13): '[ \xa0 ]ḥrḥrtm . w dš[x]n [xxx] išt aš[t] h[xxx ]išt',
#  ('KTU 1.2',
#   'III',
#   14): '[ \xa0 ]y . yblmm . ub[l xxx] ṯ[x]xk . yrd[ xxx] i[xxxx i]n . bn',
#  ('KTU 1.2',
#   'III',
#   15): '[ \xa0 ]nn [.] nrt [.] ilm [.] špš . tšu . gh . w t[ṣḥ . šm]ˤ . mˤ',
#  ('KTU 1.2',
#   'III',
#   16): '[xx yṯ]ir  . ṯr . il . abk . l pn . zbl . ym . l pn [. t]pṭ [.] nhr',
#  ('KTU 1.2',
#   'III',
#   17): '[ik . a]l  . yšmˤk . ṯr . [i]l . abk . l ysˤ . [a]lt [.] ṯbtk [.] l y[hpk ]',
#  ('KTU 1.2',
#   'III',
#   18): '[ksa  . ]mlkk . l yṯbr . ḫṭ [.] mṯpṭk . w yˤn . ˤṯ[t]r. d[m ] . kx[ ]',
#  ('KTU 1.2',
#   'III',
#   19): '[l y]qḥ . by . ṯr . il . aby . ank . in  . bt [. l]y [. km .] ilm .',
#  ('KTU 1.2',
#   'III',
#   20): '[qd]š  lbdm . ard . b npšny . trḥṣn . kṯrm[ yṯ]b b [bt]',
#  ('KTU 1.2',
#   'III',
#   21): '[zbl . ]ym . b hkl . ṯpṭ . nh[r] . yṯir  . ṯr . il [.] abh . l p[n . z]bl y[m]',
#  ('KTU 1.2',
#   'III',
#   22): '[l pn . ṯpṭ . nhr  .]mlkt . [w ]im . l mlkt . wn [.] in . aṯt [. l]k . k[m ]',
#  ('KTU 1.2', 'III', 23): '[ilm x x x x x x x x ]. zbl . ym . yṯ[ṯb ]ṯpṭ . nhr',
#  ('KTU 1.2',
#   'III',
#   24): '[x x x x x x x x x x x x x x x x]x x yšlḥn . w yˤn ˤṯtr',
#  ('KTU 1.2', 'III', 25): '[x x x x x x x x x x x x x x x x x x ]l/d[ ]',
#  ('KTU 1.2',
#   'IV',
#   1): '[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]yd[y] . ḫtt . mtt .[xxx]',
#  ('KTU 1.2',
#   'IV',
#   2): '[ \xa0 \xa0 \xa0 \xa0 \xa0 ]ḥy . n[pš ]l ašṣi .hm . ap . amr[t]',
#  ('KTU 1.2',
#   'IV',
#   3): '[ \xa0 \xa0 \xa0 \xa0 ]. w b ym . mnḫ l abd . b ym . irtm . mnm',
#  ('KTU 1.2', 'IV', 4): '[xxx]m . nhr . tlˤm . ṯm . ḥrbm . its . anšq\xa0',
#  ('KTU 1.2', 'IV', 5): '[p]itm . l arṣ . ypl . ulny . w l . ˤpr . ˤẓmny',
#  ('KTU 1.2',
#   'IV',
#   6): '[b ]ph . rgm . l yṣa . b špth . hwth . w ttn . gh . yġr',
#  ('KTU 1.2', 'IV', 7): 'tḥt . ksi . zbl . ym . w ˤn . kṯr . w ḫss . l rgmt',
#  ('KTU 1.2', 'IV', 8): 'lk . l zbl . bˤl . ṯnt . l rkb . ˤrpt . ht . ibk',
#  ('KTU 1.2', 'IV', 9): 'bˤlm . ht . ibk . tmḫṣ . ht . tṣmt . ṣrtk [[x x x x]]',
#  ('KTU 1.2', 'IV', 10): 'tqḥ . mlk . ˤlmk . drkt . dt . drdrk [[ṯr \xa0 ]] ',
#  ('KTU 1.2', 'IV', 11): 'kṯr ṣmdm . ynḥt . w <ḫss>  ypˤr . šmthm . šmk at',
#  ('KTU 1.2', 'IV', 12): 'ygrš . ygrš . grš ym grš ym . l ksih',
#  ('KTU 1.2', 'IV', 13): 'nhr . l kḥṯ . drkth . trtqṣ . bd bˤl . km nš',
#  ('KTU 1.2', 'IV', 14): 'r . b uṣbˤth . hlm . ktp . zbl . ym . bn ydm',
#  ('KTU 1.2', 'IV', 15): '[ṯp]ṭ [.] nhr . yrtqṣ . ṣmd . bd bˤl . km . nšr',
#  ('KTU 1.2', 'IV', 16): 'b uṣbˤth . ylm . ktp . zbl ym . bn . ydm . ṯpṭ',
#  ('KTU 1.2', 'IV', 17): 'nhr . ˤz . ym . l ymk . l tnġṣn [.] pnth . l ydlp',
#  ('KTU 1.2', 'IV', 18): 'tmnh . kṯr . ṣmdm . ynḥt . w ypˤr . šmthm',
#  ('KTU 1.2', 'IV', 19): 'šmk . at . aymr . aymr . mr . ym . mr . ym',
#  ('KTU 1.2', 'IV', 20): 'l ksih . nhr . l kḥṯ . drkth . trtqṣ',
#  ('KTU 1.2', 'IV', 21): 'bd bˤl . km . nšr b uṣbˤth . hlm . qdq',
#  ('KTU 1.2', 'IV', 22): 'd . zbl ym . bn . ˤnm . ṯpṭ . nhr . yprsḥ ym',
#  ('KTU 1.2', 'IV', 23): 'w yql . l arṣ . w yrtqṣ . ṣmd . bd bˤl',
#  ('KTU 1.2', 'IV', 24): 'km [.] nšr . b uṣbˤth . ylm . qdqd . zbl',
#  ('KTU 1.2', 'IV', 25): 'ym . bn . ˤnm . ṯpṭ . nhr . yprsḥ . ym . yql',
#  ('KTU 1.2', 'IV', 26): 'l arṣ . tnġṣn . pnth . w ydlp . tmnh',
#  ('KTU 1.2', 'IV', 27): 'yqṯ bˤl . w yšt . ym . ykly . ṯpṭ . nhr',
#  ('KTU 1.2', 'IV', 28): 'b . šm . tgˤrm . ˤṯtrt . bṯ . l aliyn . b[ˤl]',
#  ('KTU 1.2', 'IV', 29): 'bṯ . l rkb . ˤrpt . k šbyn . zb[l . ym . k]',
#  ('KTU 1.2',
#   'IV',
#   30): 'šbyn . ṯpṭ . nhr . w yṣa . b[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   31): 'ybṯ{.}nn . aliyn . bˤl . w[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   32): 'ym . l mt . b ˤlm . yml[k \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   33): 'ḥm . l šrr . w y[ˤn\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   34): 'yˤn . ym . l mt .[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   35): 'l šrr . w tˤ[n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   36): 'bˤlm . hmt . [ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   37): 'l šrr . št[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   38): 'b rišh . [\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   39): 'ibh . mš[ \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   40): 'bn . ˤnh[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]',
#  ('KTU 1.2',
#   'IV',
#   41): '[ \xa0 ]x[\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ]'}
